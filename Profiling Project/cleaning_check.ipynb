# %%
import pandas as pd

# %%
df = pd.read_csv('deliveries.csv')

# %%
df_ = pd.read_csv('deliveries_.csv')

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='str')

# %%
df['player_dismissed'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 179078 entries, 0 to 179077
# Series name: player_dismissed
# Non-Null Count  Dtype
# --------------  -----
# 8834 non-null   str
# dtypes: str(1)
# memory usage: 1.5 MB

# %%
df['player_dismissed'].isna().sum()
# Out:
# np.int64(170244)

# %%
df_['player_dismissed'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 179055 entries, 0 to 179054
# Series name: player_dismissed
# Non-Null Count   Dtype
# --------------   -----
# 179055 non-null  str
# dtypes: str(1)
# memory usage: 2.7 MB

# %%
df_['player_dismissed'].isna().sum()
# Out:
# np.int64(0)

# %%
df['player_dismissed'].isna().sum()
# Out:
# np.int64(170244)

# %%
df_['player_dismissed'].isna().sum()
# Out:
# np.int64(0)

# %%
df_new = pd.read_csv('deliveries_1.csv')

# %%
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  str
#  3   bowling_team      179078 non-null  str
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  str
#  7   non_striker       179078 non-null  str
#  8   bowler            179078 non-null  str
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...
